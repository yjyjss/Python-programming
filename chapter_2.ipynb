# %%
# String
print("AAA", end ="")
print("BBB", end = "***")
# Out:
# AAA

# %%
# para sep
print("Hello","World",sep = "**")
# Out:
# Hello**World

# %%
# format string
print(format("Welcome to Python","20s"))
print(format("Welcome to Python",">20s"))
# Out:
# Welcome to Python
#    Welcome to Python

# %% [markdown]
# 2.4 列表、元组和字典

# %%
list1=[]
list2=[2,3,4]
list3=["red","green","blue"]

# %%
list1 = [5.6,4.5,3.3,13.2]
type(list)
list[0]

# %%
len(list1)
max(list1)
min(list1)

# %% [markdown]
# **Functions**

# %%
items = "Jane john Peter Susan".split()
items = "2025/11/11".split('/')

# %%
line = input("请输入以空格分隔的三个整数：").split()
number1 = eval(line[0])
number2 = eval(line[1])
number3 = eval(line[2])
average = (number1 + number2 + number3) /3
print(number1, number2, number3,"的平均数是", average)
